# %%
## generating graph for problem 2
import matplotlib.pyplot as plt

plt.plot([842.9312131404877, 851.9587292671204, 897.8133518695831],[0.11, 1.0, 0.96], 'ro')
plt.axis([700, 1000, 0, 1.1])
plt.ylabel('training accuracy')
plt.xlabel('Duration in second')
plt.show()
